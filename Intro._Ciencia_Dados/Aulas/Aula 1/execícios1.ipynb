# %% [markdown]
# # Exercícios da Aula 1 - Edmur C. Neto - 12558492

# %% [markdown]
# 1 - Leia os dados com erro novamente, faça a limpeza e remova as duas últimas colunas.

# %%
import pandas as pd

data = pd.read_csv("/home/edmurcn/Documentos/MeusProjetos/Fis._Estat._Comp./Intro._Ciencia_Dados/data/iris-with-errors.csv", header=0)
data.head(25)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 0           5.1         3.5           1.4         0.2  duplicada
# 1           5.1         3.5           1.4         0.2  duplicada
# 2             ?           3           1.4         0.2     setosa
# 3           4.7         3.2           1.3         0.2     setosa
# 4           5.1         3.5           1.4         0.2  duplicada
# 5           NaN         3.1           1.5         0.2     setosa
# 6             5         3.6           1.4         0.2     setosa
# 7           5.4         3.9           1.7         0.4  duplicada
# 8           5.4         3.9           1.7         0.4  duplicada
# 9           4.6         3.4           1.4         NaN     setosa
# 10            5         3.4           1.5         0.2     setosa
# 11          4.4         2.9           1.4         0.2  duplicada
# 12          4.9         3.1           1.5         0.1     setosa
# ...

# %% [markdown]
# Substituindo os caracteres "?" por "NaN":

# %%
import numpy as np

data = data.replace("?", np.nan)
data.head(25)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 0           5.1         3.5           1.4         0.2  duplicada
# 1           5.1         3.5           1.4         0.2  duplicada
# 2           NaN           3           1.4         0.2     setosa
# 3           4.7         3.2           1.3         0.2     setosa
# 4           5.1         3.5           1.4         0.2  duplicada
# 5           NaN         3.1           1.5         0.2     setosa
# 6             5         3.6           1.4         0.2     setosa
# 7           5.4         3.9           1.7         0.4  duplicada
# 8           5.4         3.9           1.7         0.4  duplicada
# 9           4.6         3.4           1.4         NaN     setosa
# 10            5         3.4           1.5         0.2     setosa
# 11          4.4         2.9           1.4         0.2  duplicada
# 12          4.9         3.1           1.5         0.1     setosa
# ...

# %% [markdown]
# Remoção dos caracteres "NaN":

# %%
data = data.dropna()
data.head(25)
# Out:
#    sepal_length sepal_width  petal_length petal_width    species
# 0           5.1         3.5           1.4         0.2  duplicada
# 1           5.1         3.5           1.4         0.2  duplicada
# 3           4.7         3.2           1.3         0.2     setosa
# 4           5.1         3.5           1.4         0.2  duplicada
# 6             5         3.6           1.4         0.2     setosa
# 7           5.4         3.9           1.7         0.4  duplicada
# 8           5.4         3.9           1.7         0.4  duplicada
# 10            5         3.4           1.5         0.2     setosa
# 11          4.4         2.9           1.4         0.2  duplicada
# 12          4.9         3.1           1.5         0.1     setosa
# 13          5.4         3.7           1.5         0.2     setosa
# 14          4.4         2.9           1.4         0.2  duplicada
# 15          4.8         3.4           1.6         0.2     setosa
# ...

# %% [markdown]
# Remoção das linhas duplicadas:

# %%
data = data.drop_duplicates()

Y = np.array(data[data.columns[0:data.shape[1]-1]], dtype=float) #array para comparação

print("Tabela Iris sem erros: \n")
print("Colunas excluídas:", data.columns[[3,4]])

data = data.drop(data.columns[[3,4]], axis=1)

data.head(25)
# Out:
# Tabela Iris sem erros:
#
# Colunas excluídas: Index(['petal_width', 'species'], dtype='object')
#    sepal_length sepal_width  petal_length
# 0           5.1         3.5           1.4
# 3           4.7         3.2           1.3
# 6             5         3.6           1.4
# 7           5.4         3.9           1.7
# 10            5         3.4           1.5
# 11          4.4         2.9           1.4
# 12          4.9         3.1           1.5
# 13          5.4         3.7           1.5
# 15          4.8         3.4           1.6
# 16          4.8           3           1.4
# 18          4.3           3           1.1
# 19          5.8           4           1.2
# 20          5.7         4.4           1.5
# 22          5.1         3.5           1.4

# %% [markdown]
# 2 - Leia os dados com erro novamente e insira a mediana de cada atributo onde for encontrada NaN.

# %%
data = pd.read_csv("/home/edmurcn/Documentos/MeusProjetos/Fis._Estat._Comp./Intro._Ciencia_Dados/data/iris-with-errors.csv", header=0)
data = data.replace('?', np.nan)

# %%
#carregando os dados para uma matriz, removendo a última coluna de classificação

X = np.array(data[data.columns[0:data.shape[1]-1]], dtype=float)

median = np.nanmedian(X, axis=0) #cálculo da mediana de cada coluna

for i in np.arange(0, X.shape[0]):
    for j in np.arange(0, X.shape[1]):
        if (np.isnan(X[i,j]) == True):
            X[i,j] = median[j] # substituindo a mediana

print(X)
# Out:
# [[5.1  3.5  1.4  0.2 ]
#  [5.1  3.5  1.4  0.2 ]
#  [5.05 3.   1.4  0.2 ]
#  [4.7  3.2  1.3  0.2 ]
#  [5.1  3.5  1.4  0.2 ]
#  [5.05 3.1  1.5  0.2 ]
#  [5.   3.6  1.4  0.2 ]
#  [5.4  3.9  1.7  0.4 ]
#  [5.4  3.9  1.7  0.4 ]
#  [4.6  3.4  1.4  0.2 ]
#  [5.   3.4  1.5  0.2 ]
#  [4.4  2.9  1.4  0.2 ]
#  [4.9  3.1  1.5  0.1 ]
#  [5.4  3.7  1.5  0.2 ]
#  [4.4  2.9  1.4  0.2 ]
#  [4.8  3.4  1.6  0.2 ]
#  [4.8  3.   1.4  0.1 ]
#  [4.4  2.9  1.4  0.2 ]
#  [4.3  3.   1.1  0.1 ]
#  [5.8  4.   1.2  0.2 ]
#  [5.7  4.4  1.5  0.4 ]
#  [5.4  3.9  1.3  0.2 ]
#  [5.1  3.5  1.4  0.3 ]
#  [5.7  3.45 1.7  0.3 ]
#  [5.05 3.8  1.5  0.3 ]]

# %% [markdown]
# Para uma melhor visualização do resultado obtido pelos dois processos de limpeza dos dados, podemos comparar a distribuição das variáveis de cada coluna em cada um dos casos:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
fig, ax = plt.subplots() 

for i in np.arange(0, X.shape[1]):
    sns.kdeplot(data=X[:,i], label = f"Coluna {i+1} de X")
    sns.kdeplot(data=Y[:,i], label = f"Coluna {i+1} de Y")
    plt.legend()
    plt.show()

# %% [markdown]
# Vemos que para algumas colunas os dados tiveram distribuições parecidas, porém para outras houveram algumas divergências entre os dois métodos.

# %% [markdown]
# 3 - Conside os dados da Iris e mostre a distribuição de probabilidades de cada uma das variáveis após a normalização e padronização.

# %%
data = pd.read_csv("/home/edmurcn/Documentos/MeusProjetos/Fis._Estat._Comp./Intro._Ciencia_Dados/data/iris.csv", header=0)
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
from sklearn.preprocessing import MinMaxScaler

X = np.array(data[data.columns[0:data.shape[1]-1]], dtype=float)

scaler = MinMaxScaler(feature_range = (0,1)) #Função da normalização

X_norm = scaler.fit_transform(X)

print(X_norm)
# Out:
# [[0.22222222 0.625      0.06779661 0.04166667]
#  [0.16666667 0.41666667 0.06779661 0.04166667]
#  [0.11111111 0.5        0.05084746 0.04166667]
#  [0.08333333 0.45833333 0.08474576 0.04166667]
#  [0.19444444 0.66666667 0.06779661 0.04166667]
#  [0.30555556 0.79166667 0.11864407 0.125     ]
#  [0.08333333 0.58333333 0.06779661 0.08333333]
#  [0.19444444 0.58333333 0.08474576 0.04166667]
#  [0.02777778 0.375      0.06779661 0.04166667]
#  [0.16666667 0.45833333 0.08474576 0.        ]
#  [0.30555556 0.70833333 0.08474576 0.04166667]
#  [0.13888889 0.58333333 0.10169492 0.04166667]
#  [0.13888889 0.41666667 0.06779661 0.        ]
#  [0.         0.41666667 0.01694915 0.        ]
#  [0.41666667 0.83333333 0.03389831 0.04166667]
#  [0.38888889 1.         0.08474576 0.125     ]
#  [0.30555556 0.79166667 0.05084746 0.125     ]
#  [0.22222222 0.625      0.06779661 0.08333333]
#  [0.38888889 0.75       0.11864407 0.08333333]
#  [0.22222222 0.75       0.08474576 0.08333333]
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

fig, ax = plt.subplots()

for i in np.arange(0, X_norm.shape[1]):
    sns.kdeplot(X_norm[:,i], ax=ax, label=f"Coluna {i+1}", fill=False)

plt.title("Distribuição de Frequência \n (Normalização)")

plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler().fit(X)
rescalerX = scale.transform(X)

sns.set(style="whitegrid")

fig, ax = plt.subplots()

for i in np.arange(0, rescalerX.shape[1]):
    sns.kdeplot(rescalerX[:,i], ax=ax, label=f"Coluna {i+1}", fill=False)

plt.xlabel("Valores")
plt.ylabel("Probabilidade")
plt.title("Densidade de Probabilidade \n (Padronização)")

plt.legend()
plt.show()

# %% [markdown]
# 4 - Reamostre os dados da Iris e selecione 10 elementos em cada classe.

# %%
data = pd.read_csv("/home/edmurcn/Documentos/MeusProjetos/Fis._Estat._Comp./Intro._Ciencia_Dados/data/iris.csv", header=0)

classes = np.unique(data[data.columns[4]])
number = 0

for i in classes:
    data = data.replace(i, number)
    number += 1

X = np.array(data, dtype = int)

select = []
count = 0
tipo = -1

while tipo <= 2:
    i = 0
    count = 0
    tipo += 1
    for i in np.arange(0,data.shape[0]):
        if count <= 9 and X[i,4] == tipo:
            select.append(classes[tipo])
            count += 1

a = 0

print(select)
# Out:
# ['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'virginica', 'virginica', 'virginica', 'virginica', 'virginica', 'virginica', 'virginica', 'virginica', 'virginica', 'virginica']

# %% [markdown]
# 5 - Monte um boxplot para cada variável dos dados da Iris.

# %%
import seaborn as sns

data = pd.read_csv("/home/edmurcn/Documentos/MeusProjetos/Fis._Estat._Comp./Intro._Ciencia_Dados/data/iris.csv", header=0)

sns.set(style = "whitegrid")

for i in range(0,4):
    plt.figure(figsize = (8,8))
    sns.boxplot(x='species', y=data.columns[i], data=data)
    plt.xlabel = "Espécies"
    plt.ylabel = data.columns[i]
    plt.show()

# %% [markdown]
# 6 - Encontre os outliers nos dados das bases Iris e BostonHouse.

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

classificador = (((data[data.columns[0:data.shape[1]-1]] < Q1 - 1.5*IQR) | (data[data.columns[0:data.shape[1]-1]] > Q3 + 1.5*IQR)))
v = classificador.any(axis=1)

v.head(20)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
outliers_iris = data.loc[data.index[list(v)]]

print(outliers_iris)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 15           5.7          4.4           1.5          0.4      setosa
# 32           5.2          4.1           1.5          0.1      setosa
# 33           5.5          4.2           1.4          0.2      setosa
# 60           5.0          2.0           3.5          1.0  versicolor
